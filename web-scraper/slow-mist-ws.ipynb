# %% [markdown]
# # Sena Labs: slowmist.io Web Scraping Activity
#
# #### Goal: Extract exploit specific data from html/xml text data
# Extract vectors: protocol_name, Date, amount_lost, attack_type, description_text
#
# The following data extracted will be an introductory method to how the Sena REKT Report dataset will use methods such as webscraping to autonmously upload and valid attack data within the DeFi ecosystem.
#
# The description text is especially important to extract because in a future project it will be analyzed using Natural Language Processing(NLP) to attach weights to words using Python's nltk package.

# %%
import pandas as pd
from pandas import DataFrame

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import requests
import re
from bs4 import BeautifulSoup

import datetime

# %matplotlib inline

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

# %%
# Importing slowmist.io main page -- Page 1
url = "https://hacked.slowmist.io/en/"
page = requests.get(url)
html = urlopen(url)

# %%
def getHTMLdoc(url):
        response = requests.get(url)
        return response.text

# %%
html_doc = getHTMLdoc(url)

# %%
soup = BeautifulSoup(html_doc, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="width=device-width, initial-scale=1.0, user-scalable=no, minimum-scale=1.0, maximum-scale=1.0" name="viewport"/>
#   <meta content="email=no,telephone=no" name="format-detection">
#    <meta content="no-cache, no-store, must-revalidate" http-equiv="Cache-Control">
#     <meta content="no-cache" http-equiv="Pragma"/>
#     <meta content="0" http-equiv="Expires"/>
#     <title>
#      SlowMist Hacked - SlowMist Zone
#     </title>
#     <link href="/static/archives/images/favicon.ico" rel="shortcut icon"/>
#     <link href="/static/archives/css/basic.css" rel="stylesheet"/>
#     <link href="/static/archives/css/en.css" rel="stylesheet"/>
#    </meta>
#   </meta>
#  </head>
#  <body>
#   <div class="header header-index clearfix">
#    <div class="logo">
#     <a href="/en/">
#      <img src="/static/archives/images/logo.png"/>
#     </a>
#    </div>
#    <ul class="nav">
#     <li>
#      <a class="cur" href="/en/">
#       Home
#      </a>
#     </li>
#     <li>
#      <a href="/en/statistics/?c=all&amp;d=all">
#       Statistics
#      </a>
#     </li>
#     <li>
#      <a href="https://www.slowmist.com/en/" target="_blank">
#       SlowMist
#      </a>
#     </li>
#     <li>
#      <a href="https://www.slowmist.io/en/" target="_blank">
#       SlowMist Zone
#      </a>
#     </li>
#    </ul>
#    <div class="search-box">
#     <i class="icon-search">
#     </i>
#     <form action="/en/search/" method="post">
#      <input name="csrfmiddlewaretoken" type="hidden" value="XsbtmjzdiVnlTKlnaq1j8KB8HxqtFtObegQxpvnU7TStImGUQj7ddfRgVDLmDGUt"/>
#      <input class="input-search" name="q" placeholder="Keywords" required="" type="search"/>
#     </form>
#    </div>
#    <a class="language-en" href="/">
#     中文
#    </a>
#   </div>
#   <div class="banner-box">
#    <div class="banner-con clearfix">
#     <div class="banner-info">
#      <p>
#       The total amount of money lost by blockchain hackers is about
#      </p>
#      <p>
#       $ 23,886,344,914.74
#      </p>
#      <p>
#       Total hack events 614
#      </p>
#     </div>
#     <div class="banner-img">
#      <img src="/static/archives/images/banner.gif"/>
#     </div>
#    </div>
#   </div>
#   <div class="case-box">
#    <div class="case-nav">
#     <dl class="clearfix">
#      <dd class="cur">
#       <a href="/en/">
#        All
#       </a>
#      </dd>
#      <dd>
#       <a href="/en/?c=Blockchain">
#        Blockchain
#       </a>
#      </dd>
#      <dd>
#       <a href="/en/?c=Exchange">
#        Exchange
#       </a>
#      </dd>
#      <dd>
#       <a href="/en/?c=Wallet">
#        Wallet
#       </a>
#      </dd>
#      <dd>
#       <a href="/en/?c=ETH">
#        ETH Ecosystem
#       </a>
#      </dd>
#      <dd>
#       <a href="/en/?c=BSC">
#        BSC Ecosystem
#       </a>
#      </dd>
#      <dd>
#       <a href="/en/?c=Tron">
#        Tron Ecosystem
#       </a>
#      </dd>
#      <dd>
#       <a href="/en/?c=EOS">
#        EOS Ecosystem
#       </a>
#      </dd>
#      <dd>
#       <a href="/en/?c=Polygon">
#        Polygon Ecosystem
#       </a>
#      </dd>
#      <dd>
#       <a href="/en/?c=HECO">
#        HECO Ecosystem
#       </a>
#      </dd>
#      <dd>
#       <a href="/en/?c=Other">
#        Other
#       </a>
#      </dd>
#     </dl>
#    </div>
#    <div class="case-content-num">
#     <p>
#      <em class="num">
#       614
#      </em>
#      hack event(s)
#     </p>
#    </div>
#    <div class="case-content">
#     <ul>
#      <li>
#       <span class="time">
#        2022-01-15
#       </span>
#       <h3>
#        <em>
#         Hacked target:
#        </em>
#        CityDAO
#       </h3>
#       <p>
#        <em>
#         Description of the event:
#        </em>
#        CityDAO, an Ethereum-based community blockchain city project, has posted that the CityDAO Discord administrator account has been hacked. 29.67 ETH ($95,000) funds were stolen by hackers using stolen admin accounts to post fake land airdrop messages. The attacked administrator, "Lyons800," tweeted that the attack was a "ridiculous security breach from Discord."
#       </p>
#       <p>
#        <span>
#         <em>
#          Amount of loss:
#         </em>
#         29.67 ETH
#        </span>
#        <span>
#         <em>
#          Attack method:
#         </em>
#         Discord admin account hacked
#        </span>
#       </p>
#      </li>
#      <li>
#       <span class="time">
#        2022-01-15
#       </span>
#       <h3>
#        <em>
#         Hacked target:
#        </em>
#        RariCapital
#       </h3>
#       <p>
#        <em>
#         Description of the event:
#        </em>
#        According to a tweet from Float Protocol, the FLOAT/USDC UniV3 pool has approximately $1 million in funding due to the Float Protocol Pool 90 on the RariCapital pool being affected by the lack of liquidity of the Uniswap V3 FLOAT/USDC oracle, leading to severe price manipulation. It was stolen, leaving about $550,000 in FLOAT/USDC in Uniswap V3. The hackers then returned $250,000 of the stolen funds.
#       </p>
#       <p>
#        <span>
#         <em>
#          Amount of loss:
#         </em>
#         $ 200,000
#        </span>
#        <span>
#         <em>
#          Attack method:
#         </em>
#         price manipulation
#        </span>
#       </p>
#      </li>
#      <li>
#       <span class="time">
#        2022-01-13
#       </span>
#       <h3>
#        <em>
#         Hacked target:
#        </em>
#        Frosties
#       </h3>
#       <p>
#        <em>
#         Description of the event:
#        </em>
#        The creator of the NFT project Frosties absconded with the money, causing investors to lose more than $1 million. According to available information, there are 8,888 NFTs in the series with a floor price of 0.04 ETH, roughly over $120. Within an hour, all NFTs were sold, but instead of getting their assets, investors found out that the project developers closed all communication with community members. Etherscan data shows that developers have moved most of the funds from the OpenSea account to another wallet.
#       </p>
#       <p>
#        <span>
#         <em>
#          Amount of loss:
#         </em>
#         $ 1,000,000
#        </span>
#        <span>
#         <em>
#          Attack method:
#         </em>
#         Scam
#        </span>
#       </p>
#      </li>
#      <li>
#       <span class="time">
#        2022-01-12
#       </span>
#       <h3>
#        <em>
#         Hacked target:
#        </em>
#        Multiple IDO Projects
#       </h3>
#       <p>
#        <em>
#         Description of the event:
#        </em>
#        7 IDO projects on BSC are suspected to be running, namely $GOTEM (gotEM), $ONEP (HarmonyPad), $HBARP (HbarPad), $MPLAY (MetaPlay), $ELIT (Electrinity) and $PEE (MicroPee) $QDrop (QuizDrop), swept away more than 5,744 WBNB, and the funds were transferred out through Tornado.Cash.
#       </p>
#       <p>
#        <span>
#         <em>
#          Amount of loss:
#         </em>
#         5744 BNB
#        </span>
#        <span>
#         <em>
#          Attack method:
#         </em>
#         Scam
#        </span>
#       </p>
#      </li>
#      <li>
#       <span class="time">
#        2022-01-11
#       </span>
#       <h3>
#        <em>
#         Hacked target:
#        </em>
#        LooksRare
#       </h3>
#       <p>
#        <em>
#         Description of the event:
#        </em>
#        NFT marketplace LooksRare suffered a DDoS attack hours after its launch, resulting in a brief offline. Some users reported that they could not connect their wallets and list their NFTs. The LooksRare team quickly restored the site, but wallet issues persisted.
#       </p>
#       <p>
#        <span>
#         <em>
#          Amount of loss:
#         </em>
#         -
#        </span>
#        <span>
#         <em>
#          Attack method:
#         </em>
#         DDos attack
#        </span>
#       </p>
#      </li>
#      <li>
#       <span class="time">
#        2022-01-10
#       </span>
#       <h3>
#        <em>
#         Hacked target:
#        </em>
#        Lympo
#       </h3>
#       <p>
#        <em>
#         Description of the event:
#        </em>
#        Sports NFT platform Lympo suffered a hot wallet security breach, losing 165.2 million LMT tokens worth $18.7 million in the hack. Ten different project wallets were compromised in the attack. Quotes show that the LMT price plummeted 92% to $0.0093 after hackers moved and sold the loot in the project’s hot wallet.
#       </p>
#       <p>
#        <span>
#         <em>
#          Amount of loss:
#         </em>
#         $ 18,700,000
#        </span>
#        <span>
#         <em>
#          Attack method:
#         </em>
#         Hot Wallet Security Vulnerability
#        </span>
#       </p>
#      </li>
#      <li>
#       <span class="time">
#        2022-01-09
#       </span>
#       <h3>
#        <em>
#         Hacked target:
#        </em>
#        LCX
#       </h3>
#       <p>
#        <em>
#         Description of the event:
#        </em>
#        LCX tweeted that there had been a security incident, that it was investigating the situation and had stopped its withdrawal function. The majority of the assets are being sold as ETH and are being transferred through TornadoCash with a cumulative damage value of over US $6 million.
#       </p>
#       <p>
#        <span>
#         <em>
#          Amount of loss:
#         </em>
#         $ 6,000,000
#        </span>
#        <span>
#         <em>
#          Attack method:
#         </em>
#         Stolen hot wallet
#        </span>
#       </p>
#      </li>
#      <li>
#       <span class="time">
#        2022-01-09
#       </span>
#       <h3>
#        <em>
#         Hacked target:
#        </em>
#        Arbitrum One
#       </h3>
#       <p>
#        <em>
#         Description of the event:
#        </em>
#        According to the block explorer, the last block of the Arbitrum One network was generated at 18:29 Beijing time, and no new blocks and new transactions have been generated for more than 2 hours. At the same time, the Matemask wallet cannot connect to the Arbitrum One network.
#       </p>
#       <p>
#        <span>
#         <em>
#          Amount of loss:
#         </em>
#         -
#        </span>
#        <span>
#         <em>
#          Attack method:
#         </em>
#         Downtime
#        </span>
#       </p>
#      </li>
#      <li>
#       <span class="time">
#        2022-01-07
#       </span>
#       <h3>
#        <em>
#         Hacked target:
#        </em>
#        StoboxCompany
#       </h3>
#       <p>
#        <em>
#         Description of the event:
#        </em>
#        The digital asset service provider StoboxCompany was attacked by hackers, and its official statement that the private key had been leaked, affected by this, the token fell by 96.93%. StoboxCompany officially stated that the address of the deployer of Stobox tokens was hacked. Since the address of the deployer of ETH and BSC is the same, all reserve funds have been stolen or liquidated. Remind users to stop buying/selling, and the official will restore the STBU snapshot to the last transaction before the hacker attack.
#       </p>
#       <p>
#        <span>
#         <em>
#          Amount of loss:
#         </em>
#         -
#        </span>
#        <span>
#         <em>
#          Attack method:
#         </em>
#         Private key leak
#        </span>
#       </p>
#      </li>
#      <li>
#       <span class="time">
#        2022-01-07
#       </span>
#       <h3>
#        <em>
#         Hacked target:
#        </em>
#        DaoMetaland
#       </h3>
#       <p>
#        <em>
#         Description of the event:
#        </em>
#        Rug Pull occurred in the DaoMetaland project on BSC, and the current loss exceeds 640 BNB. DaoMetaland's official Twitter has been deleted.
#       </p>
#       <p>
#        <span>
#         <em>
#          Amount of loss:
#         </em>
#         640 BNB
#        </span>
#        <span>
#         <em>
#          Attack method:
#         </em>
#         Scam
#        </span>
#       </p>
#      </li>
#      <li>
#       <span class="time">
#        2022-01-06
#       </span>
#       <h3>
#        <em>
#         Hacked target:
#        </em>
#        Bored Bunny
#       </h3>
#       <p>
#        <em>
#         Description of the event:
#        </em>
#        NFT project Bored Bunny is suspected of being a Rug Pull project. Some netizens said that 2,000 ETH raised have been transferred out, and some of them have been transferred to Binan. In addition, this address had similar behavior 1-2 months ago, associated with 2 NFT items that almost went to zero. Currently Bored Bunny's Discord has turned off all people all channels to speak.
#       </p>
#       <p>
#        <span>
#         <em>
#          Amount of loss:
#         </em>
#         2,000 ETH
#        </span>
#        <span>
#         <em>
#          Attack method:
#         </em>
#         Scam
#        </span>
#       </p>
#      </li>
#      <li>
#       <span class="time">
#        2022-01-05
#       </span>
#       <h3>
#        <em>
#         Hacked target:
#        </em>
#        Moon Rabbit
#       </h3>
#       <p>
#        <em>
#         Description of the event:
#        </em>
#        Moon Rabbit runs away.
#       </p>
#       <p>
#        <span>
#         <em>
#          Amount of loss:
#         </em>
#         -
#        </span>
#        <span>
#         <em>
#          Attack method:
#         </em>
#         Scam
#        </span>
#       </p>
#      </li>
#      <li>
#       <span class="time">
#        2022-01-04
#       </span>
#       <h3>
#        <em>
#         Hacked target:
#        </em>
#        Arbix Finance
#       </h3>
#       <p>
#        <em>
#         Description of the event:
#        </em>
#        Arbix Finance ran away, taking away more than 10 million US dollars. Arbix Finance bills itself as an arbitrage project on BSC, where users can deposit funds in a single asset vault in order to "get the best return with low risk". Starting at around 3 am on January 4, the project siphoned users’ funds from the treasury and deleted their websites, Twitter and Telegram accounts.
#       </p>
#       <p>
#        <span>
#         <em>
#          Amount of loss:
#         </em>
#         $ 10,000,000
#        </span>
#        <span>
#         <em>
#          Attack method:
#         </em>
#         Scam
#        </span>
#       </p>
#      </li>
#      <li>
#       <span class="time">
#        2022-01-01
#       </span>
#       <h3>
#        <em>
#         Hacked target:
#        </em>
#        Tinyman Pools
#       </h3>
#       <p>
#        <em>
#         Description of the event:
#        </em>
#        An attack occurred at Tinyman Pools on January 1 /2, algorand-based automated market maker (AMM) Tinyman tweeted. The attack exploits a previously unknown hole in the contract and allows the attacker to extract assets from a pool to which he has no access. So far, attacks have been executed on multiple pools, but not all of them have been attacked.
#       </p>
#       <p>
#        <span>
#         <em>
#          Amount of loss:
#         </em>
#         -
#        </span>
#        <span>
#         <em>
#          Attack method:
#         </em>
#         Contract vulnerabilities
#        </span>
#       </p>
#      </li>
#      <li>
#       <span class="time">
#        2021-12-31
#       </span>
#       <h3>
#        <em>
#         Hacked target:
#        </em>
#        Vesper Finance
#       </h3>
#       <p>
#        <em>
#         Description of the event:
#        </em>
#        Vesper Finance tweeted that its No. 23 lending pool Vesper Lend beta launched on the interest rate agreement Fuse has been attacked again. The attacker manipulated an oracle and depleted the beta test borrowing pool of DAI, ETH, WBTC, and USDC of approximately $1 million. This is not an attack on the Vesper contract, no VSP or VVSP is threatened. Vesper has banned the lending of all tokens in Beta Vesper Lend Rari Pool #23, and also switched the oracle from VUSD/USDC to VUSD/ETH (Uni v3). Prior to this, the Vesper Lend loan pool on Rari Fuse was attacked, and the attacker made a profit of 3 million US dollars.
#       </p>
#       <p>
#        <span>
#         <em>
#          Amount of loss:
#         </em>
#         $ 1,000,000
#        </span>
#        <span>
#         <em>
#          Attack method:
#         </em>
#         Manipulate the oracle
#        </span>
#       </p>
#      </li>
#      <li>
#       <span class="time">
#        2021-12-30
#       </span>
#       <h3>
#        <em>
#         Hacked target:
#        </em>
#        SashimiSwap
#       </h3>
#       <p>
#        <em>
#         Description of the event:
#        </em>
#        SashimiSwap was attacked because of a logical error in the swap function.
#       </p>
#       <p>
#        <span>
#         <em>
#          Amount of loss:
#         </em>
#         -
#        </span>
#        <span>
#         <em>
#          Attack method:
#         </em>
#         logical error
#        </span>
#       </p>
#      </li>
#      <li>
#       <span class="time">
#        2021-12-28
#       </span>
#       <h3>
#        <em>
#         Hacked target:
#        </em>
#        MASK Token
#       </h3>
#       <p>
#        <em>
#         Description of the event:
#        </em>
#        On December 28th, according to Twitter user coby.eth, a fake MetaMask governance token was created and launched on the DEXTools platform. The creator of the token used malicious code to make users browse the token information, and a pop-up interface showed that the MASK Token was verified and displayed A forged platform verification mark (blue certification symbol) is displayed. coby.eth stated that after the transaction volume exceeded US$1 million, the token was transformed into a "Pixiu plate", and users could only buy but not sell. According to browser data, the total transaction volume of this "Pixiu Pan" MASK Token is close to 10 million U.S. dollars, with a total of 642 related transactions and close to 400 addresses.
#       </p>
#       <p>
#        <span>
#         <em>
#          Amount of loss:
#         </em>
#         -
#        </span>
#        <span>
#         <em>
#          Attack method:
#         </em>
#         Scam
#        </span>
#       </p>
#      </li>
#      <li>
#       <span class="time">
#        2021-12-27
#       </span>
#       <h3>
#        <em>
#         Hacked target:
#        </em>
#        MetaSwap
#       </h3>
#       <p>
#        <em>
#         Description of the event:
#        </em>
#        The MetaSwap on-chain project on the BSC transferred its running assets. A total of 1,100 BNB of stolen funds were transferred to the Tornado.cash wallet (BSC version), and the price of MGAS tokens fell by 46.99%.
#       </p>
#       <p>
#        <span>
#         <em>
#          Amount of loss:
#         </em>
#         1,100 BNB
#        </span>
#        <span>
#         <em>
#          Attack method:
#         </em>
#         Scam
#        </span>
#       </p>
#      </li>
#      <li>
#       <span class="time">
#        2021-12-27
#       </span>
#       <h3>
#        <em>
#         Hacked target:
#        </em>
#        MetaDAO
#       </h3>
#       <p>
#        <em>
#         Description of the event:
#        </em>
#        According to news, METADAO took a Rug Pull, took away the funds (800 ETH, about 3.25 million US dollars), and has been transferred to Tornado.cash mixed currency.
#       </p>
#       <p>
#        <span>
#         <em>
#          Amount of loss:
#         </em>
#         800 ETH
#        </span>
#        <span>
#         <em>
#          Attack method:
#         </em>
#         Scam
#        </span>
#       </p>
#      </li>
#      <li>
#       <span class="time">
#        2021-12-23
#       </span>
#       <h3>
#        <em>
#         Hacked target:
#        </em>
#        Monkey Kindom
#       </h3>
#       <p>
#        <em>
#         Description of the event:
#        </em>
#        The NFT project Monkey Kindom stated that hackers stole $1.3 million in SOL from the community through a security breach in discord. The hacker first attacked Grape, the solution to authenticate users on Solana, and took advantage of the vulnerability to take over an administrative account that posted a phishing link in the announcement channel of Monkey Kindom discord.
#       </p>
#       <p>
#        <span>
#         <em>
#          Amount of loss:
#         </em>
#         $ 1,300,000
#        </span>
#        <span>
#         <em>
#          Attack method:
#         </em>
#         Phishing attack
#        </span>
#       </p>
#      </li>
#     </ul>
#    </div>
#    <ul class="pagination">
#     <li class="disabled">
#      <a href=" javascript:; ">
#       First
#      </a>
#     </li>
#     <li class="disabled">
#      <a href=" javascript:; ">
#       «
#      </a>
#     </li>
#     <li class="disabled">
#      <a href="javascript:;">
#       Page 1 of 31
#      </a>
#     </li>
#     <li>
#      <a href=" /en/?c=&amp;page=2 ">
#       »
#      </a>
#     </li>
#     <li>
#      <a href=" /en/?c=&amp;page=31 ">
#       Last
#      </a>
#     </li>
#    </ul>
#   </div>
#   <div class="footer">
#    <p>
#     Copyright © 2019 SlowMist Hacked All Rights Reserved.
#    </p>
#    <div class="i-submit">
#     <a href="https://www.slowmist.io/threat-intelligence.html?utm_source=hacked" target="_blank">
#      <i>
#      </i>
#      Submit Comments
#     </a>
#    </div>
#   </div>
#   <div class="sidebar-submit-box">
#    <a class="back-to-top" href="javascript:;" title="TOP">
#     <em>
#      TOP
#     </em>
#    </a>
#   </div>
#   <script src="/static/archives/js/jquery-3.5.1.min.js" type="text/javascript">
#   </script>
#   <script src="/static/archives/js/hacked.js" type="text/javascript">
#   </script>
#  </body>
# </html>

# %%
# Get the title
title = soup.title
print(title)
# Out:
# <title>SlowMist Hacked - SlowMist Zone</title>

# %%
text = soup.get_text()

# %%
print(soup.text)
# Out:
# SlowMist Hacked - SlowMist Zone
#
#
#
#
#
#
#
#
# Home
# Statistics
# SlowMist
# SlowMist Zone
#
#
#
#
#
#
#
#
# 中文
#
#
#
#
# The total amount of money lost by blockchain hackers is about
# $ 23,886,344,914.74
# Total hack events 614
#
#
#
#
#
#
#
#
#
# All
# Blockchain
# Exchange
# Wallet
# ETH Ecosystem
# BSC Ecosystem
# Tron Ecosystem
# EOS Ecosystem
# Polygon Ecosystem
# HECO Ecosystem
# Other
#
#
#
# 614 hack event(s)
#
#
#
#
# 2022-01-15
# Hacked target: CityDAO
# Description of the event: CityDAO, an Ethereum-based community blockchain city project, has posted that the CityDAO Discord administrator account has been hacked. 29.67 ETH ($95,000) funds were stolen by hackers using stolen admin accounts to post fake land airdrop messages. The attacked administrator, "Lyons800," tweeted that the attack was a "ridiculous security breach from Discord."
# Amount of loss:
#
#                             29.67 ETH
#
#                     Attack method: Discord admin account hacked
#
#
# 2022-01-15
# Hacked target: RariCapital
# Description of the event: According to a tweet from Float Protocol, the FLOAT/USDC UniV3 pool has approximately $1 million in funding due to the Float Protocol Pool 90 on the RariCapital pool being affected by the lack of liquidity of the Uniswap V3 FLOAT/USDC oracle, leading to severe price manipulation. It was stolen, leaving about $550,000 in FLOAT/USDC in Uniswap V3. The hackers then returned $250,000 of the stolen funds.
# Amount of loss:
#
#                             $ 200,000
#
#                     Attack method: price manipulation
#
#
# 2022-01-13
# Hacked target: Frosties
# Description of the event: The creator of the NFT project Frosties absconded with the money, causing investors to lose more than $1 million. According to available information, there are 8,888 NFTs in the series with a floor price of 0.04 ETH, roughly over $120. Within an hour, all NFTs were sold, but instead of getting their assets, investors found out that the project developers closed all communication with community members. Etherscan data shows that developers have moved most of the funds from the OpenSea account to another wallet.
# Amount of loss:
#
#                             $ 1,000,000
#
#                     Attack method: Scam
#
#
# 2022-01-12
# Hacked target: Multiple IDO Projects
# Description of the event: 7 IDO projects on BSC are suspected to be running, namely $GOTEM (gotEM), $ONEP (HarmonyPad), $HBARP (HbarPad), $MPLAY (MetaPlay), $ELIT (Electrinity) and $PEE (MicroPee) $QDrop (QuizDrop), swept away more than 5,744 WBNB, and the funds were transferred out through Tornado.Cash.
# Amount of loss:
#
#                             5744 BNB
#
#                     Attack method: Scam
#
#
# 2022-01-11
# Hacked target: LooksRare
# Description of the event: NFT marketplace LooksRare suffered a DDoS attack hours after its launch, resulting in a brief offline. Some users reported that they could not connect their wallets and list their NFTs. The LooksRare team quickly restored the site, but wallet issues persisted.
# Amount of loss:
#
#                             -
#
#                     Attack method: DDos attack
#
#
# 2022-01-10
# Hacked target: Lympo
# Description of the event: Sports NFT platform Lympo suffered a hot wallet security breach, losing 165.2 million LMT tokens worth $18.7 million in the hack. Ten different project wallets were compromised in the attack. Quotes show that the LMT price plummeted 92% to $0.0093 after hackers moved and sold the loot in the project’s hot wallet.
# Amount of loss:
#
#                             $ 18,700,000
#
#                     Attack method: Hot Wallet Security Vulnerability
#
#
# 2022-01-09
# Hacked target: LCX
# Description of the event: LCX tweeted that there had been a security incident, that it was investigating the situation and had stopped its withdrawal function. The majority of the assets are being sold as ETH and are being transferred through TornadoCash with a cumulative damage value of over US $6 million.
# Amount of loss:
#
#                             $ 6,000,000
#
#                     Attack method: Stolen hot wallet
#
#
# 2022-01-09
# Hacked target: Arbitrum One
# Description of the event: According to the block explorer, the last block of the Arbitrum One network was generated at 18:29 Beijing time, and no new blocks and new transactions have been generated for more than 2 hours. At the same time, the Matemask wallet cannot connect to the Arbitrum One network.
# Amount of loss:
#
#                             -
#
#                     Attack method: Downtime
#
#
# 2022-01-07
# Hacked target: StoboxCompany
# Description of the event: The digital asset service provider StoboxCompany was attacked by hackers, and its official statement that the private key had been leaked, affected by this, the token fell by 96.93%. StoboxCompany officially stated that the address of the deployer of Stobox tokens was hacked. Since the address of the deployer of ETH and BSC is the same, all reserve funds have been stolen or liquidated. Remind users to stop buying/selling, and the official will restore the STBU snapshot to the last transaction before the hacker attack.
# Amount of loss:
#
#                             -
#
#                     Attack method: Private key leak
#
#
# 2022-01-07
# Hacked target: DaoMetaland
# Description of the event: Rug Pull occurred in the DaoMetaland project on BSC, and the current loss exceeds 640 BNB. DaoMetaland's official Twitter has been deleted.
# Amount of loss:
#
#                             640 BNB
#
#                     Attack method: Scam
#
#
# 2022-01-06
# Hacked target: Bored Bunny
# Description of the event: NFT project Bored Bunny is suspected of being a Rug Pull project. Some netizens said that 2,000 ETH raised have been transferred out, and some of them have been transferred to Binan. In addition, this address had similar behavior 1-2 months ago, associated with 2 NFT items that almost went to zero. Currently Bored Bunny's Discord has turned off all people all channels to speak.
# Amount of loss:
#
#                             2,000 ETH
#
#                     Attack method: Scam
#
#
# 2022-01-05
# Hacked target: Moon Rabbit
# Description of the event: Moon Rabbit runs away.
# Amount of loss:
#
#                             -
#
#                     Attack method: Scam
#
#
# 2022-01-04
# Hacked target: Arbix Finance
# Description of the event: Arbix Finance ran away, taking away more than 10 million US dollars. Arbix Finance bills itself as an arbitrage project on BSC, where users can deposit funds in a single asset vault in order to "get the best return with low risk". Starting at around 3 am on January 4, the project siphoned users’ funds from the treasury and deleted their websites, Twitter and Telegram accounts.
# Amount of loss:
#
#                             $ 10,000,000
#
#                     Attack method: Scam
#
#
# 2022-01-01
# Hacked target: Tinyman Pools
# Description of the event: An attack occurred at Tinyman Pools on January 1 /2, algorand-based automated market maker (AMM) Tinyman tweeted. The attack exploits a previously unknown hole in the contract and allows the attacker to extract assets from a pool to which he has no access. So far, attacks have been executed on multiple pools, but not all of them have been attacked.
# Amount of loss:
#
#                             -
#
#                     Attack method: Contract vulnerabilities
#
#
# 2021-12-31
# Hacked target: Vesper Finance
# Description of the event: Vesper Finance tweeted that its No. 23 lending pool Vesper Lend beta launched on the interest rate agreement Fuse has been attacked again. The attacker manipulated an oracle and depleted the beta test borrowing pool of DAI, ETH, WBTC, and USDC of approximately $1 million. This is not an attack on the Vesper contract, no VSP or VVSP is threatened. Vesper has banned the lending of all tokens in Beta Vesper Lend Rari Pool #23, and also switched the oracle from VUSD/USDC to VUSD/ETH (Uni v3). Prior to this, the Vesper Lend loan pool on Rari Fuse was attacked, and the attacker made a profit of 3 million US dollars.
# Amount of loss:
#
#                             $ 1,000,000
#
#                     Attack method: Manipulate the oracle
#
#
# 2021-12-30
# Hacked target: SashimiSwap
# Description of the event: SashimiSwap was attacked because of a logical error in the swap function.
# Amount of loss:
#
#                             -
#
#                     Attack method: logical error
#
#
# 2021-12-28
# Hacked target: MASK Token
# Description of the event: On December 28th, according to Twitter user coby.eth, a fake MetaMask governance token was created and launched on the DEXTools platform. The creator of the token used malicious code to make users browse the token information, and a pop-up interface showed that the MASK Token was verified and displayed A forged platform verification mark (blue certification symbol) is displayed. coby.eth stated that after the transaction volume exceeded US$1 million, the token was transformed into a "Pixiu plate", and users could only buy but not sell. According to browser data, the total transaction volume of this "Pixiu Pan" MASK Token is close to 10 million U.S. dollars, with a total of 642 related transactions and close to 400 addresses.
# Amount of loss:
#
#                             -
#
#                     Attack method: Scam
#
#
# 2021-12-27
# Hacked target: MetaSwap
# Description of the event: The MetaSwap on-chain project on the BSC transferred its running assets. A total of 1,100 BNB of stolen funds were transferred to the Tornado.cash wallet (BSC version), and the price of MGAS tokens fell by 46.99%.
# Amount of loss:
#
#                             1,100 BNB
#
#                     Attack method: Scam
#
#
# 2021-12-27
# Hacked target: MetaDAO
# Description of the event: According to news, METADAO took a Rug Pull, took away the funds (800 ETH, about 3.25 million US dollars), and has been transferred to Tornado.cash mixed currency.
# Amount of loss:
#
#                             800 ETH
#
#                     Attack method: Scam
#
#
# 2021-12-23
# Hacked target: Monkey Kindom
# Description of the event: The NFT project Monkey Kindom stated that hackers stole $1.3 million in SOL from the community through a security breach in discord. The hacker first attacked Grape, the solution to authenticate users on Solana, and took advantage of the vulnerability to take over an administrative account that posted a phishing link in the announcement channel of Monkey Kindom discord.
# Amount of loss:
#
#                             $ 1,300,000
#
#                     Attack method: Phishing attack
#
#
#
#
#  First
#  «
# Page 1 of 31
#  »
#  Last
#
#
#
# Copyright © 2019 SlowMist Hacked All Rights Reserved.
# Submit Comments
#
# TOP

# %%
# Finding all list elements. List elements contain the 
soup.find_all("li")
# Out:
# [<li><a class="cur" href="/en/">Home</a></li>,
#  <li><a href="/en/statistics/?c=all&amp;d=all">Statistics</a></li>,
#  <li><a href="https://www.slowmist.com/en/" target="_blank">SlowMist</a></li>,
#  <li><a href="https://www.slowmist.io/en/" target="_blank">SlowMist Zone</a></li>,
#  <li>
#  <span class="time">2022-01-15</span>
#  <h3><em>Hacked target: </em>CityDAO</h3>
#  <p><em>Description of the event: </em>CityDAO, an Ethereum-based community blockchain city project, has posted that the CityDAO Discord administrator account has been hacked. 29.67 ETH ($95,000) funds were stolen by hackers using stolen admin accounts to post fake land airdrop messages. The attacked administrator, "Lyons800," tweeted that the attack was a "ridiculous security breach from Discord."</p>
#  <p><span><em>Amount of loss: </em>
#
#                              29.67 ETH
#
#                      </span><span><em>Attack method: </em>Discord admin account hacked</span></p>
#  </li>,
#  <li>
#  <span class="time">2022-01-15</span>
#  <h3><em>Hacked target: </em>RariCapital</h3>
#  <p><em>Description of the event: </em>According to a tweet from Float Protocol, the FLOAT/USDC UniV3 pool has approximately $1 million in funding due to the Float Protocol Pool 90 on the RariCapital pool being affected by the lack of liquidity of the Uniswap V3 FLOAT/USDC oracle, leading to severe price manipulation. It was stolen, leaving about $550,000 in FLOAT/USDC in Uniswap V3. The hackers then returned $250,000 of the stolen funds.</p>
#  <p><span><em>Amount of loss: </em>
#
#                              $ 200,000
#
#                      </span><span><em>Attack method: </em>price manipulation</span></p>
#  </li>,
#  <li>
#  <span class="time">2022-01-13</span>
#  <h3><em>Hacked target: </em>Frosties</h3>
#  <p><em>Description of the event: </em>The creator of the NFT project Frosties absconded with the money, causing investors to lose more than $1 million. According to available information, there are 8,888 NFTs in the series with a floor price of 0.04 ETH, roughly over $120. Within an hour, all NFTs were sold, but instead of getting their assets, investors found out that the project developers closed all communication with community members. Etherscan data shows that developers have moved most of the funds from the OpenSea account to another wallet.</p>
#  <p><span><em>Amount of loss: </em>
#
#                              $ 1,000,000
#
#                      </span><span><em>Attack method: </em>Scam</span></p>
#  </li>,
#  <li>
#  <span class="time">2022-01-12</span>
#  <h3><em>Hacked target: </em>Multiple IDO Projects</h3>
#  <p><em>Description of the event: </em>7 IDO projects on BSC are suspected to be running, namely $GOTEM (gotEM), $ONEP (HarmonyPad), $HBARP (HbarPad), $MPLAY (MetaPlay), $ELIT (Electrinity) and $PEE (MicroPee) $QDrop (QuizDrop), swept away more than 5,744 WBNB, and the funds were transferred out through Tornado.Cash.</p>
#  <p><span><em>Amount of loss: </em>
#
#                              5744 BNB
#
#                      </span><span><em>Attack method: </em>Scam</span></p>
#  </li>,
#  <li>
#  <span class="time">2022-01-11</span>
#  <h3><em>Hacked target: </em>LooksRare</h3>
#  <p><em>Description of the event: </em>NFT marketplace LooksRare suffered a DDoS attack hours after its launch, resulting in a brief offline. Some users reported that they could not connect their wallets and list their NFTs. The LooksRare team quickly restored the site, but wallet issues persisted.</p>
#  <p><span><em>Amount of loss: </em>
#
#                              -
#
#                      </span><span><em>Attack method: </em>DDos attack</span></p>
#  </li>,
#  <li>
#  <span class="time">2022-01-10</span>
#  <h3><em>Hacked target: </em>Lympo</h3>
#  <p><em>Description of the event: </em>Sports NFT platform Lympo suffered a hot wallet security breach, losing 165.2 million LMT tokens worth $18.7 million in the hack. Ten different project wallets were compromised in the attack. Quotes show that the LMT price plummeted 92% to $0.0093 after hackers moved and sold the loot in the project’s hot wallet.</p>
#  <p><span><em>Amount of loss: </em>
#
#                              $ 18,700,000
#
#                      </span><span><em>Attack method: </em>Hot Wallet Security Vulnerability</span></p>
#  </li>,
#  <li>
#  <span class="time">2022-01-09</span>
#  <h3><em>Hacked target: </em>LCX</h3>
#  <p><em>Description of the event: </em>LCX tweeted that there had been a security incident, that it was investigating the situation and had stopped its withdrawal function. The majority of the assets are being sold as ETH and are being transferred through TornadoCash with a cumulative damage value of over US $6 million.</p>
#  <p><span><em>Amount of loss: </em>
#
#                              $ 6,000,000
#
#                      </span><span><em>Attack method: </em>Stolen hot wallet</span></p>
#  </li>,
#  <li>
#  <span class="time">2022-01-09</span>
#  <h3><em>Hacked target: </em>Arbitrum One</h3>
#  <p><em>Description of the event: </em>According to the block explorer, the last block of the Arbitrum One network was generated at 18:29 Beijing time, and no new blocks and new transactions have been generated for more than 2 hours. At the same time, the Matemask wallet cannot connect to the Arbitrum One network.</p>
#  <p><span><em>Amount of loss: </em>
#
#                              -
#
#                      </span><span><em>Attack method: </em>Downtime</span></p>
#  </li>,
#  <li>
#  <span class="time">2022-01-07</span>
#  <h3><em>Hacked target: </em>StoboxCompany</h3>
#  <p><em>Description of the event: </em>The digital asset service provider StoboxCompany was attacked by hackers, and its official statement that the private key had been leaked, affected by this, the token fell by 96.93%. StoboxCompany officially stated that the address of the deployer of Stobox tokens was hacked. Since the address of the deployer of ETH and BSC is the same, all reserve funds have been stolen or liquidated. Remind users to stop buying/selling, and the official will restore the STBU snapshot to the last transaction before the hacker attack.</p>
#  <p><span><em>Amount of loss: </em>
#
#                              -
#
#                      </span><span><em>Attack method: </em>Private key leak</span></p>
#  </li>,
#  <li>
#  <span class="time">2022-01-07</span>
#  <h3><em>Hacked target: </em>DaoMetaland</h3>
#  <p><em>Description of the event: </em>Rug Pull occurred in the DaoMetaland project on BSC, and the current loss exceeds 640 BNB. DaoMetaland's official Twitter has been deleted.</p>
#  <p><span><em>Amount of loss: </em>
#
#                              640 BNB
#
#                      </span><span><em>Attack method: </em>Scam</span></p>
#  </li>,
#  <li>
#  <span class="time">2022-01-06</span>
#  <h3><em>Hacked target: </em>Bored Bunny</h3>
#  <p><em>Description of the event: </em>NFT project Bored Bunny is suspected of being a Rug Pull project. Some netizens said that 2,000 ETH raised have been transferred out, and some of them have been transferred to Binan. In addition, this address had similar behavior 1-2 months ago, associated with 2 NFT items that almost went to zero. Currently Bored Bunny's Discord has turned off all people all channels to speak.</p>
#  <p><span><em>Amount of loss: </em>
#
#                              2,000 ETH
#
#                      </span><span><em>Attack method: </em>Scam</span></p>
#  </li>,
#  <li>
#  <span class="time">2022-01-05</span>
#  <h3><em>Hacked target: </em>Moon Rabbit</h3>
#  <p><em>Description of the event: </em>Moon Rabbit runs away.</p>
#  <p><span><em>Amount of loss: </em>
#
#                              -
#
#                      </span><span><em>Attack method: </em>Scam</span></p>
#  </li>,
#  <li>
#  <span class="time">2022-01-04</span>
#  <h3><em>Hacked target: </em>Arbix Finance</h3>
#  <p><em>Description of the event: </em>Arbix Finance ran away, taking away more than 10 million US dollars. Arbix Finance bills itself as an arbitrage project on BSC, where users can deposit funds in a single asset vault in order to "get the best return with low risk". Starting at around 3 am on January 4, the project siphoned users’ funds from the treasury and deleted their websites, Twitter and Telegram accounts.</p>
#  <p><span><em>Amount of loss: </em>
#
#                              $ 10,000,000
#
#                      </span><span><em>Attack method: </em>Scam</span></p>
#  </li>,
#  <li>
#  <span class="time">2022-01-01</span>
#  <h3><em>Hacked target: </em>Tinyman Pools</h3>
#  <p><em>Description of the event: </em>An attack occurred at Tinyman Pools on January 1 /2, algorand-based automated market maker (AMM) Tinyman tweeted. The attack exploits a previously unknown hole in the contract and allows the attacker to extract assets from a pool to which he has no access. So far, attacks have been executed on multiple pools, but not all of them have been attacked.</p>
#  <p><span><em>Amount of loss: </em>
#
#                              -
#
#                      </span><span><em>Attack method: </em>Contract vulnerabilities</span></p>
#  </li>,
#  <li>
#  <span class="time">2021-12-31</span>
#  <h3><em>Hacked target: </em>Vesper Finance</h3>
#  <p><em>Description of the event: </em>Vesper Finance tweeted that its No. 23 lending pool Vesper Lend beta launched on the interest rate agreement Fuse has been attacked again. The attacker manipulated an oracle and depleted the beta test borrowing pool of DAI, ETH, WBTC, and USDC of approximately $1 million. This is not an attack on the Vesper contract, no VSP or VVSP is threatened. Vesper has banned the lending of all tokens in Beta Vesper Lend Rari Pool #23, and also switched the oracle from VUSD/USDC to VUSD/ETH (Uni v3). Prior to this, the Vesper Lend loan pool on Rari Fuse was attacked, and the attacker made a profit of 3 million US dollars.</p>
#  <p><span><em>Amount of loss: </em>
#
#                              $ 1,000,000
#
#                      </span><span><em>Attack method: </em>Manipulate the oracle</span></p>
#  </li>,
#  <li>
#  <span class="time">2021-12-30</span>
#  <h3><em>Hacked target: </em>SashimiSwap</h3>
#  <p><em>Description of the event: </em>SashimiSwap was attacked because of a logical error in the swap function.</p>
#  <p><span><em>Amount of loss: </em>
#
#                              -
#
#                      </span><span><em>Attack method: </em>logical error</span></p>
#  </li>,
#  <li>
#  <span class="time">2021-12-28</span>
#  <h3><em>Hacked target: </em>MASK Token</h3>
#  <p><em>Description of the event: </em>On December 28th, according to Twitter user coby.eth, a fake MetaMask governance token was created and launched on the DEXTools platform. The creator of the token used malicious code to make users browse the token information, and a pop-up interface showed that the MASK Token was verified and displayed A forged platform verification mark (blue certification symbol) is displayed. coby.eth stated that after the transaction volume exceeded US$1 million, the token was transformed into a "Pixiu plate", and users could only buy but not sell. According to browser data, the total transaction volume of this "Pixiu Pan" MASK Token is close to 10 million U.S. dollars, with a total of 642 related transactions and close to 400 addresses.</p>
#  <p><span><em>Amount of loss: </em>
#
#                              -
#
#                      </span><span><em>Attack method: </em>Scam</span></p>
#  </li>,
#  <li>
#  <span class="time">2021-12-27</span>
#  <h3><em>Hacked target: </em>MetaSwap</h3>
#  <p><em>Description of the event: </em>The MetaSwap on-chain project on the BSC transferred its running assets. A total of 1,100 BNB of stolen funds were transferred to the Tornado.cash wallet (BSC version), and the price of MGAS tokens fell by 46.99%.</p>
#  <p><span><em>Amount of loss: </em>
#
#                              1,100 BNB
#
#                      </span><span><em>Attack method: </em>Scam</span></p>
#  </li>,
#  <li>
#  <span class="time">2021-12-27</span>
#  <h3><em>Hacked target: </em>MetaDAO</h3>
#  <p><em>Description of the event: </em>According to news, METADAO took a Rug Pull, took away the funds (800 ETH, about 3.25 million US dollars), and has been transferred to Tornado.cash mixed currency.</p>
#  <p><span><em>Amount of loss: </em>
#
#                              800 ETH
#
#                      </span><span><em>Attack method: </em>Scam</span></p>
#  </li>,
#  <li>
#  <span class="time">2021-12-23</span>
#  <h3><em>Hacked target: </em>Monkey Kindom</h3>
#  <p><em>Description of the event: </em>The NFT project Monkey Kindom stated that hackers stole $1.3 million in SOL from the community through a security breach in discord. The hacker first attacked Grape, the solution to authenticate users on Solana, and took advantage of the vulnerability to take over an administrative account that posted a phishing link in the announcement channel of Monkey Kindom discord.</p>
#  <p><span><em>Amount of loss: </em>
#
#                              $ 1,300,000
#
#                      </span><span><em>Attack method: </em>Phishing attack</span></p>
#  </li>,
#  <li class="disabled"><a href=" javascript:; "> First </a></li>,
#  <li class="disabled"><a href=" javascript:; "> « </a></li>,
#  <li class="disabled"><a href="javascript:;">Page 1 of 31</a></li>,
#  <li><a href=" /en/?c=&amp;page=2 "> »</a></li>,
#  <li><a href=" /en/?c=&amp;page=31 "> Last </a></li>]

# %%
ptcl_table = soup.find_all('h3')
ptcl_table
# Out:
# [<h3><em>Hacked target: </em>CityDAO</h3>,
#  <h3><em>Hacked target: </em>RariCapital</h3>,
#  <h3><em>Hacked target: </em>Frosties</h3>,
#  <h3><em>Hacked target: </em>Multiple IDO Projects</h3>,
#  <h3><em>Hacked target: </em>LooksRare</h3>,
#  <h3><em>Hacked target: </em>Lympo</h3>,
#  <h3><em>Hacked target: </em>LCX</h3>,
#  <h3><em>Hacked target: </em>Arbitrum One</h3>,
#  <h3><em>Hacked target: </em>StoboxCompany</h3>,
#  <h3><em>Hacked target: </em>DaoMetaland</h3>,
#  <h3><em>Hacked target: </em>Bored Bunny</h3>,
#  <h3><em>Hacked target: </em>Moon Rabbit</h3>,
#  <h3><em>Hacked target: </em>Arbix Finance</h3>,
#  <h3><em>Hacked target: </em>Tinyman Pools</h3>,
#  <h3><em>Hacked target: </em>Vesper Finance</h3>,
#  <h3><em>Hacked target: </em>SashimiSwap</h3>,
#  <h3><em>Hacked target: </em>MASK Token</h3>,
#  <h3><em>Hacked target: </em>MetaSwap</h3>,
#  <h3><em>Hacked target: </em>MetaDAO</h3>,
#  <h3><em>Hacked target: </em>Monkey Kindom</h3>]

# %%
dummie_ptcl_table = []
for row in ptcl_table:
        r = row.get_text()
        dummie_ptcl_table.append(r)

# %%
dummie_ptcl_table[0:5]
# Out:
# ['Hacked target: CityDAO',
#  'Hacked target: RariCapital',
#  'Hacked target: Frosties',
#  'Hacked target: Multiple IDO Projects',
#  'Hacked target: LooksRare']

# %%
cleaned_ptcl_table = []
for item in dummie_ptcl_table:
    new_item = item.replace('Hacked target: ', "")
    cleaned_ptcl_table.append(new_item)

# %%
cleaned_ptcl_table[0:5]
# Out:
# ['CityDAO', 'RariCapital', 'Frosties', 'Multiple IDO Projects', 'LooksRare']

# %%
len(cleaned_ptcl_table)
# Out:
# 20

# %%
dates_table = soup.find_all('span', attrs = {'class':'time'})
dates_table
# Out:
# [<span class="time">2022-01-15</span>,
#  <span class="time">2022-01-15</span>,
#  <span class="time">2022-01-13</span>,
#  <span class="time">2022-01-12</span>,
#  <span class="time">2022-01-11</span>,
#  <span class="time">2022-01-10</span>,
#  <span class="time">2022-01-09</span>,
#  <span class="time">2022-01-09</span>,
#  <span class="time">2022-01-07</span>,
#  <span class="time">2022-01-07</span>,
#  <span class="time">2022-01-06</span>,
#  <span class="time">2022-01-05</span>,
#  <span class="time">2022-01-04</span>,
#  <span class="time">2022-01-01</span>,
#  <span class="time">2021-12-31</span>,
#  <span class="time">2021-12-30</span>,
#  <span class="time">2021-12-28</span>,
#  <span class="time">2021-12-27</span>,
#  <span class="time">2021-12-27</span>,
#  <span class="time">2021-12-23</span>]

# %%
cleaned_dates_table = []
for item in soup.select('span.time'):
    cleaned_dates_table.append(item.text)

# %%
cleaned_dates_table[0:5]
# Out:
# ['2022-01-15', '2022-01-15', '2022-01-13', '2022-01-12', '2022-01-11']

# %%
final_dates = []
for item in cleaned_dates_table:
    i = datetime.datetime.strptime(item, '%Y-%m-%d').strftime('%m/%d/%Y')
    final_dates.append(i)

# %%
final_dates[0:5]
# Out:
# ['01/15/2022', '01/15/2022', '01/13/2022', '01/12/2022', '01/11/2022']

# %%
len(final_dates)
# Out:
# 20

# %%
table = soup.find_all('span')
table[0:5]
# Out:
# [<span class="time">2022-01-15</span>,
#  <span><em>Amount of loss: </em>
#
#                              29.67 ETH
#
#                      </span>,
#  <span><em>Attack method: </em>Discord admin account hacked</span>,
#  <span class="time">2022-01-15</span>,
#  <span><em>Amount of loss: </em>
#
#                              $ 200,000
#
#                      </span>]

# %%
content_table = []
for i in table:
    j = i.get_text()
    content_table.append(j)
    print(j)
# Out:
# 2022-01-15
# Amount of loss:
#
#                             29.67 ETH
#
#
# Attack method: Discord admin account hacked
# 2022-01-15
# Amount of loss:
#
#                             $ 200,000
#
#
# Attack method: price manipulation
# 2022-01-13
# Amount of loss:
#
#                             $ 1,000,000
#
#
# Attack method: Scam
# 2022-01-12
# Amount of loss:
#
#                             5744 BNB
#
#
# Attack method: Scam
# 2022-01-11
# Amount of loss:
#
#                             -
#
#
# Attack method: DDos attack
# 2022-01-10
# Amount of loss:
#
#                             $ 18,700,000
#
#
# Attack method: Hot Wallet Security Vulnerability
# 2022-01-09
# Amount of loss:
#
#                             $ 6,000,000
#
#
# Attack method: Stolen hot wallet
# 2022-01-09
# Amount of loss:
#
#                             -
#
#
# Attack method: Downtime
# 2022-01-07
# Amount of loss:
#
#                             -
#
#
# Attack method: Private key leak
# 2022-01-07
# Amount of loss:
#
#                             640 BNB
#
#
# Attack method: Scam
# 2022-01-06
# Amount of loss:
#
#                             2,000 ETH
#
#
# Attack method: Scam
# 2022-01-05
# Amount of loss:
#
#                             -
#
#
# Attack method: Scam
# 2022-01-04
# Amount of loss:
#
#                             $ 10,000,000
#
#
# Attack method: Scam
# 2022-01-01
# Amount of loss:
#
#                             -
#
#
# Attack method: Contract vulnerabilities
# 2021-12-31
# Amount of loss:
#
#                             $ 1,000,000
#
#
# Attack method: Manipulate the oracle
# 2021-12-30
# Amount of loss:
#
#                             -
#
#
# Attack method: logical error
# 2021-12-28
# Amount of loss:
#
#                             -
#
#
# Attack method: Scam
# 2021-12-27
# Amount of loss:
#
#                             1,100 BNB
#
#
# Attack method: Scam
# 2021-12-27
# Amount of loss:
#
#                             800 ETH
#
#
# Attack method: Scam
# 2021-12-23
# Amount of loss:
#
#                             $ 1,300,000
#
#
# Attack method: Phishing attack

# %%
content_table[0:10] 
# This is a list of all the dates, amount lost, and attack methods
# Data cleaning before extraction is the best method to getting
# the rest of the data needed for the DataFrame
# Out:
# ['2022-01-15',
#  'Amount of loss: \n                        \n                            29.67 ETH\n                        \n                    ',
#  'Attack method: Discord admin account hacked',
#  '2022-01-15',
#  'Amount of loss: \n                        \n                            $ 200,000\n                        \n                    ',
#  'Attack method: price manipulation',
#  '2022-01-13',
#  'Amount of loss: \n                        \n                            $ 1,000,000\n                        \n                    ',
#  'Attack method: Scam',
#  '2022-01-12']

# %%
amt_table = []
for row in content_table:
        k = re.sub(' \s+', '', row)
        k = k.strip('\t\n')
        amt_table.append(k)

# %%
amt_table[0:10]
# Out:
# ['2022-01-15',
#  'Amount of loss:29.67 ETH',
#  'Attack method: Discord admin account hacked',
#  '2022-01-15',
#  'Amount of loss:$ 200,000',
#  'Attack method: price manipulation',
#  '2022-01-13',
#  'Amount of loss:$ 1,000,000',
#  'Attack method: Scam',
#  '2022-01-12']

# %%
new_amt_table = []
for item in amt_table:
    if ('Amount of loss:' in item):
        item = item.strip('Amount of loss:')
        new_amt_table.append(item)

# %%
new_amt_table[0:10]
# Out:
# ['29.67 ETH',
#  '$ 200,000',
#  '$ 1,000,000',
#  '5744 BNB',
#  '-',
#  '$ 18,700,000',
#  '$ 6,000,000',
#  '-',
#  '-',
#  '640 BNB']

# %%
len(new_amt_table)
# Out:
# 20

# %%
amt_table[0:10]
# Out:
# ['2022-01-15',
#  'Amount of loss:29.67 ETH',
#  'Attack method: Discord admin account hacked',
#  '2022-01-15',
#  'Amount of loss:$ 200,000',
#  'Attack method: price manipulation',
#  '2022-01-13',
#  'Amount of loss:$ 1,000,000',
#  'Attack method: Scam',
#  '2022-01-12']

# %%
attack_table = []
for item in amt_table:
    if ('Attack method:' in item):
        i = item.lstrip('Attack method: ')
        attack_table.append(i)

# %%
attack_table[0:10]
# Out:
# ['Discord admin account hacked',
#  'price manipulation',
#  'Scam',
#  'Scam',
#  'DDos attack',
#  'Hot Wallet Security Vulnerability',
#  'Stolen hot wallet',
#  'Downtime',
#  'Private key leak',
#  'Scam']

# %%
len(attack_table)
# Out:
# 20

# %%
table = soup.find_all('p')
table
# Out:
# [<p>The total amount of money lost by blockchain hackers is about</p>,
#  <p>$ 23,886,344,914.74</p>,
#  <p>Total hack events 614</p>,
#  <p><em class="num">614</em> hack event(s)</p>,
#  <p><em>Description of the event: </em>CityDAO, an Ethereum-based community blockchain city project, has posted that the CityDAO Discord administrator account has been hacked. 29.67 ETH ($95,000) funds were stolen by hackers using stolen admin accounts to post fake land airdrop messages. The attacked administrator, "Lyons800," tweeted that the attack was a "ridiculous security breach from Discord."</p>,
#  <p><span><em>Amount of loss: </em>
#
#                              29.67 ETH
#
#                      </span><span><em>Attack method: </em>Discord admin account hacked</span></p>,
#  <p><em>Description of the event: </em>According to a tweet from Float Protocol, the FLOAT/USDC UniV3 pool has approximately $1 million in funding due to the Float Protocol Pool 90 on the RariCapital pool being affected by the lack of liquidity of the Uniswap V3 FLOAT/USDC oracle, leading to severe price manipulation. It was stolen, leaving about $550,000 in FLOAT/USDC in Uniswap V3. The hackers then returned $250,000 of the stolen funds.</p>,
#  <p><span><em>Amount of loss: </em>
#
#                              $ 200,000
#
#                      </span><span><em>Attack method: </em>price manipulation</span></p>,
#  <p><em>Description of the event: </em>The creator of the NFT project Frosties absconded with the money, causing investors to lose more than $1 million. According to available information, there are 8,888 NFTs in the series with a floor price of 0.04 ETH, roughly over $120. Within an hour, all NFTs were sold, but instead of getting their assets, investors found out that the project developers closed all communication with community members. Etherscan data shows that developers have moved most of the funds from the OpenSea account to another wallet.</p>,
#  <p><span><em>Amount of loss: </em>
#
#                              $ 1,000,000
#
#                      </span><span><em>Attack method: </em>Scam</span></p>,
#  <p><em>Description of the event: </em>7 IDO projects on BSC are suspected to be running, namely $GOTEM (gotEM), $ONEP (HarmonyPad), $HBARP (HbarPad), $MPLAY (MetaPlay), $ELIT (Electrinity) and $PEE (MicroPee) $QDrop (QuizDrop), swept away more than 5,744 WBNB, and the funds were transferred out through Tornado.Cash.</p>,
#  <p><span><em>Amount of loss: </em>
#
#                              5744 BNB
#
#                      </span><span><em>Attack method: </em>Scam</span></p>,
#  <p><em>Description of the event: </em>NFT marketplace LooksRare suffered a DDoS attack hours after its launch, resulting in a brief offline. Some users reported that they could not connect their wallets and list their NFTs. The LooksRare team quickly restored the site, but wallet issues persisted.</p>,
#  <p><span><em>Amount of loss: </em>
#
#                              -
#
#                      </span><span><em>Attack method: </em>DDos attack</span></p>,
#  <p><em>Description of the event: </em>Sports NFT platform Lympo suffered a hot wallet security breach, losing 165.2 million LMT tokens worth $18.7 million in the hack. Ten different project wallets were compromised in the attack. Quotes show that the LMT price plummeted 92% to $0.0093 after hackers moved and sold the loot in the project’s hot wallet.</p>,
#  <p><span><em>Amount of loss: </em>
#
#                              $ 18,700,000
#
#                      </span><span><em>Attack method: </em>Hot Wallet Security Vulnerability</span></p>,
#  <p><em>Description of the event: </em>LCX tweeted that there had been a security incident, that it was investigating the situation and had stopped its withdrawal function. The majority of the assets are being sold as ETH and are being transferred through TornadoCash with a cumulative damage value of over US $6 million.</p>,
#  <p><span><em>Amount of loss: </em>
#
#                              $ 6,000,000
#
#                      </span><span><em>Attack method: </em>Stolen hot wallet</span></p>,
#  <p><em>Description of the event: </em>According to the block explorer, the last block of the Arbitrum One network was generated at 18:29 Beijing time, and no new blocks and new transactions have been generated for more than 2 hours. At the same time, the Matemask wallet cannot connect to the Arbitrum One network.</p>,
#  <p><span><em>Amount of loss: </em>
#
#                              -
#
#                      </span><span><em>Attack method: </em>Downtime</span></p>,
#  <p><em>Description of the event: </em>The digital asset service provider StoboxCompany was attacked by hackers, and its official statement that the private key had been leaked, affected by this, the token fell by 96.93%. StoboxCompany officially stated that the address of the deployer of Stobox tokens was hacked. Since the address of the deployer of ETH and BSC is the same, all reserve funds have been stolen or liquidated. Remind users to stop buying/selling, and the official will restore the STBU snapshot to the last transaction before the hacker attack.</p>,
#  <p><span><em>Amount of loss: </em>
#
#                              -
#
#                      </span><span><em>Attack method: </em>Private key leak</span></p>,
#  <p><em>Description of the event: </em>Rug Pull occurred in the DaoMetaland project on BSC, and the current loss exceeds 640 BNB. DaoMetaland's official Twitter has been deleted.</p>,
#  <p><span><em>Amount of loss: </em>
#
#                              640 BNB
#
#                      </span><span><em>Attack method: </em>Scam</span></p>,
#  <p><em>Description of the event: </em>NFT project Bored Bunny is suspected of being a Rug Pull project. Some netizens said that 2,000 ETH raised have been transferred out, and some of them have been transferred to Binan. In addition, this address had similar behavior 1-2 months ago, associated with 2 NFT items that almost went to zero. Currently Bored Bunny's Discord has turned off all people all channels to speak.</p>,
#  <p><span><em>Amount of loss: </em>
#
#                              2,000 ETH
#
#                      </span><span><em>Attack method: </em>Scam</span></p>,
#  <p><em>Description of the event: </em>Moon Rabbit runs away.</p>,
#  <p><span><em>Amount of loss: </em>
#
#                              -
#
#                      </span><span><em>Attack method: </em>Scam</span></p>,
#  <p><em>Description of the event: </em>Arbix Finance ran away, taking away more than 10 million US dollars. Arbix Finance bills itself as an arbitrage project on BSC, where users can deposit funds in a single asset vault in order to "get the best return with low risk". Starting at around 3 am on January 4, the project siphoned users’ funds from the treasury and deleted their websites, Twitter and Telegram accounts.</p>,
#  <p><span><em>Amount of loss: </em>
#
#                              $ 10,000,000
#
#                      </span><span><em>Attack method: </em>Scam</span></p>,
#  <p><em>Description of the event: </em>An attack occurred at Tinyman Pools on January 1 /2, algorand-based automated market maker (AMM) Tinyman tweeted. The attack exploits a previously unknown hole in the contract and allows the attacker to extract assets from a pool to which he has no access. So far, attacks have been executed on multiple pools, but not all of them have been attacked.</p>,
#  <p><span><em>Amount of loss: </em>
#
#                              -
#
#                      </span><span><em>Attack method: </em>Contract vulnerabilities</span></p>,
#  <p><em>Description of the event: </em>Vesper Finance tweeted that its No. 23 lending pool Vesper Lend beta launched on the interest rate agreement Fuse has been attacked again. The attacker manipulated an oracle and depleted the beta test borrowing pool of DAI, ETH, WBTC, and USDC of approximately $1 million. This is not an attack on the Vesper contract, no VSP or VVSP is threatened. Vesper has banned the lending of all tokens in Beta Vesper Lend Rari Pool #23, and also switched the oracle from VUSD/USDC to VUSD/ETH (Uni v3). Prior to this, the Vesper Lend loan pool on Rari Fuse was attacked, and the attacker made a profit of 3 million US dollars.</p>,
#  <p><span><em>Amount of loss: </em>
#
#                              $ 1,000,000
#
#                      </span><span><em>Attack method: </em>Manipulate the oracle</span></p>,
#  <p><em>Description of the event: </em>SashimiSwap was attacked because of a logical error in the swap function.</p>,
#  <p><span><em>Amount of loss: </em>
#
#                              -
#
#                      </span><span><em>Attack method: </em>logical error</span></p>,
#  <p><em>Description of the event: </em>On December 28th, according to Twitter user coby.eth, a fake MetaMask governance token was created and launched on the DEXTools platform. The creator of the token used malicious code to make users browse the token information, and a pop-up interface showed that the MASK Token was verified and displayed A forged platform verification mark (blue certification symbol) is displayed. coby.eth stated that after the transaction volume exceeded US$1 million, the token was transformed into a "Pixiu plate", and users could only buy but not sell. According to browser data, the total transaction volume of this "Pixiu Pan" MASK Token is close to 10 million U.S. dollars, with a total of 642 related transactions and close to 400 addresses.</p>,
#  <p><span><em>Amount of loss: </em>
#
#                              -
#
#                      </span><span><em>Attack method: </em>Scam</span></p>,
#  <p><em>Description of the event: </em>The MetaSwap on-chain project on the BSC transferred its running assets. A total of 1,100 BNB of stolen funds were transferred to the Tornado.cash wallet (BSC version), and the price of MGAS tokens fell by 46.99%.</p>,
#  <p><span><em>Amount of loss: </em>
#
#                              1,100 BNB
#
#                      </span><span><em>Attack method: </em>Scam</span></p>,
#  <p><em>Description of the event: </em>According to news, METADAO took a Rug Pull, took away the funds (800 ETH, about 3.25 million US dollars), and has been transferred to Tornado.cash mixed currency.</p>,
#  <p><span><em>Amount of loss: </em>
#
#                              800 ETH
#
#                      </span><span><em>Attack method: </em>Scam</span></p>,
#  <p><em>Description of the event: </em>The NFT project Monkey Kindom stated that hackers stole $1.3 million in SOL from the community through a security breach in discord. The hacker first attacked Grape, the solution to authenticate users on Solana, and took advantage of the vulnerability to take over an administrative account that posted a phishing link in the announcement channel of Monkey Kindom discord.</p>,
#  <p><span><em>Amount of loss: </em>
#
#                              $ 1,300,000
#
#                      </span><span><em>Attack method: </em>Phishing attack</span></p>,
#  <p>Copyright © 2019 SlowMist Hacked All Rights Reserved. </p>]

# %%
content_table = []
for i in table:
    j = i.get_text()
    content_table.append(j)
    print(j)
# Out:
# The total amount of money lost by blockchain hackers is about
# $ 23,886,344,914.74
# Total hack events 614
# 614 hack event(s)
# Description of the event: CityDAO, an Ethereum-based community blockchain city project, has posted that the CityDAO Discord administrator account has been hacked. 29.67 ETH ($95,000) funds were stolen by hackers using stolen admin accounts to post fake land airdrop messages. The attacked administrator, "Lyons800," tweeted that the attack was a "ridiculous security breach from Discord."
# Amount of loss:
#
#                             29.67 ETH
#
#                     Attack method: Discord admin account hacked
# Description of the event: According to a tweet from Float Protocol, the FLOAT/USDC UniV3 pool has approximately $1 million in funding due to the Float Protocol Pool 90 on the RariCapital pool being affected by the lack of liquidity of the Uniswap V3 FLOAT/USDC oracle, leading to severe price manipulation. It was stolen, leaving about $550,000 in FLOAT/USDC in Uniswap V3. The hackers then returned $250,000 of the stolen funds.
# Amount of loss:
#
#                             $ 200,000
#
#                     Attack method: price manipulation
# Description of the event: The creator of the NFT project Frosties absconded with the money, causing investors to lose more than $1 million. According to available information, there are 8,888 NFTs in the series with a floor price of 0.04 ETH, roughly over $120. Within an hour, all NFTs were sold, but instead of getting their assets, investors found out that the project developers closed all communication with community members. Etherscan data shows that developers have moved most of the funds from the OpenSea account to another wallet.
# Amount of loss:
#
#                             $ 1,000,000
#
#                     Attack method: Scam
# Description of the event: 7 IDO projects on BSC are suspected to be running, namely $GOTEM (gotEM), $ONEP (HarmonyPad), $HBARP (HbarPad), $MPLAY (MetaPlay), $ELIT (Electrinity) and $PEE (MicroPee) $QDrop (QuizDrop), swept away more than 5,744 WBNB, and the funds were transferred out through Tornado.Cash.
# Amount of loss:
#
#                             5744 BNB
#
#                     Attack method: Scam
# Description of the event: NFT marketplace LooksRare suffered a DDoS attack hours after its launch, resulting in a brief offline. Some users reported that they could not connect their wallets and list their NFTs. The LooksRare team quickly restored the site, but wallet issues persisted.
# Amount of loss:
#
#                             -
#
#                     Attack method: DDos attack
# Description of the event: Sports NFT platform Lympo suffered a hot wallet security breach, losing 165.2 million LMT tokens worth $18.7 million in the hack. Ten different project wallets were compromised in the attack. Quotes show that the LMT price plummeted 92% to $0.0093 after hackers moved and sold the loot in the project’s hot wallet.
# Amount of loss:
#
#                             $ 18,700,000
#
#                     Attack method: Hot Wallet Security Vulnerability
# Description of the event: LCX tweeted that there had been a security incident, that it was investigating the situation and had stopped its withdrawal function. The majority of the assets are being sold as ETH and are being transferred through TornadoCash with a cumulative damage value of over US $6 million.
# Amount of loss:
#
#                             $ 6,000,000
#
#                     Attack method: Stolen hot wallet
# Description of the event: According to the block explorer, the last block of the Arbitrum One network was generated at 18:29 Beijing time, and no new blocks and new transactions have been generated for more than 2 hours. At the same time, the Matemask wallet cannot connect to the Arbitrum One network.
# Amount of loss:
#
#                             -
#
#                     Attack method: Downtime
# Description of the event: The digital asset service provider StoboxCompany was attacked by hackers, and its official statement that the private key had been leaked, affected by this, the token fell by 96.93%. StoboxCompany officially stated that the address of the deployer of Stobox tokens was hacked. Since the address of the deployer of ETH and BSC is the same, all reserve funds have been stolen or liquidated. Remind users to stop buying/selling, and the official will restore the STBU snapshot to the last transaction before the hacker attack.
# Amount of loss:
#
#                             -
#
#                     Attack method: Private key leak
# Description of the event: Rug Pull occurred in the DaoMetaland project on BSC, and the current loss exceeds 640 BNB. DaoMetaland's official Twitter has been deleted.
# Amount of loss:
#
#                             640 BNB
#
#                     Attack method: Scam
# Description of the event: NFT project Bored Bunny is suspected of being a Rug Pull project. Some netizens said that 2,000 ETH raised have been transferred out, and some of them have been transferred to Binan. In addition, this address had similar behavior 1-2 months ago, associated with 2 NFT items that almost went to zero. Currently Bored Bunny's Discord has turned off all people all channels to speak.
# Amount of loss:
#
#                             2,000 ETH
#
#                     Attack method: Scam
# Description of the event: Moon Rabbit runs away.
# Amount of loss:
#
#                             -
#
#                     Attack method: Scam
# Description of the event: Arbix Finance ran away, taking away more than 10 million US dollars. Arbix Finance bills itself as an arbitrage project on BSC, where users can deposit funds in a single asset vault in order to "get the best return with low risk". Starting at around 3 am on January 4, the project siphoned users’ funds from the treasury and deleted their websites, Twitter and Telegram accounts.
# Amount of loss:
#
#                             $ 10,000,000
#
#                     Attack method: Scam
# Description of the event: An attack occurred at Tinyman Pools on January 1 /2, algorand-based automated market maker (AMM) Tinyman tweeted. The attack exploits a previously unknown hole in the contract and allows the attacker to extract assets from a pool to which he has no access. So far, attacks have been executed on multiple pools, but not all of them have been attacked.
# Amount of loss:
#
#                             -
#
#                     Attack method: Contract vulnerabilities
# Description of the event: Vesper Finance tweeted that its No. 23 lending pool Vesper Lend beta launched on the interest rate agreement Fuse has been attacked again. The attacker manipulated an oracle and depleted the beta test borrowing pool of DAI, ETH, WBTC, and USDC of approximately $1 million. This is not an attack on the Vesper contract, no VSP or VVSP is threatened. Vesper has banned the lending of all tokens in Beta Vesper Lend Rari Pool #23, and also switched the oracle from VUSD/USDC to VUSD/ETH (Uni v3). Prior to this, the Vesper Lend loan pool on Rari Fuse was attacked, and the attacker made a profit of 3 million US dollars.
# Amount of loss:
#
#                             $ 1,000,000
#
#                     Attack method: Manipulate the oracle
# Description of the event: SashimiSwap was attacked because of a logical error in the swap function.
# Amount of loss:
#
#                             -
#
#                     Attack method: logical error
# Description of the event: On December 28th, according to Twitter user coby.eth, a fake MetaMask governance token was created and launched on the DEXTools platform. The creator of the token used malicious code to make users browse the token information, and a pop-up interface showed that the MASK Token was verified and displayed A forged platform verification mark (blue certification symbol) is displayed. coby.eth stated that after the transaction volume exceeded US$1 million, the token was transformed into a "Pixiu plate", and users could only buy but not sell. According to browser data, the total transaction volume of this "Pixiu Pan" MASK Token is close to 10 million U.S. dollars, with a total of 642 related transactions and close to 400 addresses.
# Amount of loss:
#
#                             -
#
#                     Attack method: Scam
# Description of the event: The MetaSwap on-chain project on the BSC transferred its running assets. A total of 1,100 BNB of stolen funds were transferred to the Tornado.cash wallet (BSC version), and the price of MGAS tokens fell by 46.99%.
# Amount of loss:
#
#                             1,100 BNB
#
#                     Attack method: Scam
# Description of the event: According to news, METADAO took a Rug Pull, took away the funds (800 ETH, about 3.25 million US dollars), and has been transferred to Tornado.cash mixed currency.
# Amount of loss:
#
#                             800 ETH
#
#                     Attack method: Scam
# Description of the event: The NFT project Monkey Kindom stated that hackers stole $1.3 million in SOL from the community through a security breach in discord. The hacker first attacked Grape, the solution to authenticate users on Solana, and took advantage of the vulnerability to take over an administrative account that posted a phishing link in the announcement channel of Monkey Kindom discord.
# Amount of loss:
#
#                             $ 1,300,000
#
#                     Attack method: Phishing attack
# Copyright © 2019 SlowMist Hacked All Rights Reserved.

# %%
content_table[0:10]
# Out:
# ['The total amount of money lost by blockchain hackers is about',
#  '$ 23,886,344,914.74',
#  'Total hack events 614',
#  '614 hack event(s)',
#  'Description of the event: CityDAO, an Ethereum-based community blockchain city project, has posted that the CityDAO Discord administrator account has been hacked. 29.67 ETH ($95,000) funds were stolen by hackers using stolen admin accounts to post fake land airdrop messages. The attacked administrator, "Lyons800," tweeted that the attack was a "ridiculous security breach from Discord."',
#  'Amount of loss: \n                        \n                            29.67 ETH\n                        \n                    Attack method: Discord admin account hacked',
#  'Description of the event: According to a tweet from Float Protocol, the FLOAT/USDC UniV3 pool has approximately $1 million in funding due to the Float Protocol Pool 90 on the RariCapital pool being affected by the lack of liquidity of the Uniswap V3 FLOAT/USDC oracle, leading to severe price manipulation. It was stolen, leaving about $550,000 in FLOAT/USDC in Uniswap V3. The hackers then returned $250,000 of the stolen funds.',
#  'Amount of loss: \n                        \n                            $ 200,000\n                        \n                    Attack method: price manipulation',
#  'Description of the event: The creator of the NFT project Frosties absconded with the money, causing investors to lose more than $1 million. According to available information, there are 8,888 NFTs in the series with a floor price of 0.04 ETH, roughly over $120. Within an hour, all NFTs were sold, but instead of getting their assets, investors found out that the project developers closed all communication with community members. Etherscan data shows that developers have moved most of the funds from the OpenSea account to another wallet.',
#  'Amount of loss: \n                        \n                            $ 1,000,000\n                        \n                    Attack method: Scam']

# %%
description_table = []
for item in content_table:
    if ('Description of the event:' in item):
        i = item.lstrip('Description of the event:')
        description_table.append(i)

# %%
description_table
# Out:
# ['CityDAO, an Ethereum-based community blockchain city project, has posted that the CityDAO Discord administrator account has been hacked. 29.67 ETH ($95,000) funds were stolen by hackers using stolen admin accounts to post fake land airdrop messages. The attacked administrator, "Lyons800," tweeted that the attack was a "ridiculous security breach from Discord."',
#  'According to a tweet from Float Protocol, the FLOAT/USDC UniV3 pool has approximately $1 million in funding due to the Float Protocol Pool 90 on the RariCapital pool being affected by the lack of liquidity of the Uniswap V3 FLOAT/USDC oracle, leading to severe price manipulation. It was stolen, leaving about $550,000 in FLOAT/USDC in Uniswap V3. The hackers then returned $250,000 of the stolen funds.',
#  'The creator of the NFT project Frosties absconded with the money, causing investors to lose more than $1 million. According to available information, there are 8,888 NFTs in the series with a floor price of 0.04 ETH, roughly over $120. Within an hour, all NFTs were sold, but instead of getting their assets, investors found out that the project developers closed all communication with community members. Etherscan data shows that developers have moved most of the funds from the OpenSea account to another wallet.',
#  '7 IDO projects on BSC are suspected to be running, namely $GOTEM (gotEM), $ONEP (HarmonyPad), $HBARP (HbarPad), $MPLAY (MetaPlay), $ELIT (Electrinity) and $PEE (MicroPee) $QDrop (QuizDrop), swept away more than 5,744 WBNB, and the funds were transferred out through Tornado.Cash.',
#  'NFT marketplace LooksRare suffered a DDoS attack hours after its launch, resulting in a brief offline. Some users reported that they could not connect their wallets and list their NFTs. The LooksRare team quickly restored the site, but wallet issues persisted.',
#  'Sports NFT platform Lympo suffered a hot wallet security breach, losing 165.2 million LMT tokens worth $18.7 million in the hack. Ten different project wallets were compromised in the attack. Quotes show that the LMT price plummeted 92% to $0.0093 after hackers moved and sold the loot in the project’s hot wallet.',
#  'LCX tweeted that there had been a security incident, that it was investigating the situation and had stopped its withdrawal function. The majority of the assets are being sold as ETH and are being transferred through TornadoCash with a cumulative damage value of over US $6 million.',
#  'According to the block explorer, the last block of the Arbitrum One network was generated at 18:29 Beijing time, and no new blocks and new transactions have been generated for more than 2 hours. At the same time, the Matemask wallet cannot connect to the Arbitrum One network.',
#  'The digital asset service provider StoboxCompany was attacked by hackers, and its official statement that the private key had been leaked, affected by this, the token fell by 96.93%. StoboxCompany officially stated that the address of the deployer of Stobox tokens was hacked. Since the address of the deployer of ETH and BSC is the same, all reserve funds have been stolen or liquidated. Remind users to stop buying/selling, and the official will restore the STBU snapshot to the last transaction before the hacker attack.',
#  "Rug Pull occurred in the DaoMetaland project on BSC, and the current loss exceeds 640 BNB. DaoMetaland's official Twitter has been deleted.",
#  "NFT project Bored Bunny is suspected of being a Rug Pull project. Some netizens said that 2,000 ETH raised have been transferred out, and some of them have been transferred to Binan. In addition, this address had similar behavior 1-2 months ago, associated with 2 NFT items that almost went to zero. Currently Bored Bunny's Discord has turned off all people all channels to speak.",
#  'Moon Rabbit runs away.',
#  'Arbix Finance ran away, taking away more than 10 million US dollars. Arbix Finance bills itself as an arbitrage project on BSC, where users can deposit funds in a single asset vault in order to "get the best return with low risk". Starting at around 3 am on January 4, the project siphoned users’ funds from the treasury and deleted their websites, Twitter and Telegram accounts.',
#  'An attack occurred at Tinyman Pools on January 1 /2, algorand-based automated market maker (AMM) Tinyman tweeted. The attack exploits a previously unknown hole in the contract and allows the attacker to extract assets from a pool to which he has no access. So far, attacks have been executed on multiple pools, but not all of them have been attacked.',
#  'Vesper Finance tweeted that its No. 23 lending pool Vesper Lend beta launched on the interest rate agreement Fuse has been attacked again. The attacker manipulated an oracle and depleted the beta test borrowing pool of DAI, ETH, WBTC, and USDC of approximately $1 million. This is not an attack on the Vesper contract, no VSP or VVSP is threatened. Vesper has banned the lending of all tokens in Beta Vesper Lend Rari Pool #23, and also switched the oracle from VUSD/USDC to VUSD/ETH (Uni v3). Prior to this, the Vesper Lend loan pool on Rari Fuse was attacked, and the attacker made a profit of 3 million US dollars.',
#  'SashimiSwap was attacked because of a logical error in the swap function.',
#  'On December 28th, according to Twitter user coby.eth, a fake MetaMask governance token was created and launched on the DEXTools platform. The creator of the token used malicious code to make users browse the token information, and a pop-up interface showed that the MASK Token was verified and displayed A forged platform verification mark (blue certification symbol) is displayed. coby.eth stated that after the transaction volume exceeded US$1 million, the token was transformed into a "Pixiu plate", and users could only buy but not sell. According to browser data, the total transaction volume of this "Pixiu Pan" MASK Token is close to 10 million U.S. dollars, with a total of 642 related transactions and close to 400 addresses.',
#  'The MetaSwap on-chain project on the BSC transferred its running assets. A total of 1,100 BNB of stolen funds were transferred to the Tornado.cash wallet (BSC version), and the price of MGAS tokens fell by 46.99%.',
#  'According to news, METADAO took a Rug Pull, took away the funds (800 ETH, about 3.25 million US dollars), and has been transferred to Tornado.cash mixed currency.',
#  'The NFT project Monkey Kindom stated that hackers stole $1.3 million in SOL from the community through a security breach in discord. The hacker first attacked Grape, the solution to authenticate users on Solana, and took advantage of the vulnerability to take over an administrative account that posted a phishing link in the announcement channel of Monkey Kindom discord.']

# %%
len(description_table)
# Out:
# 20

# %%
df = pd.DataFrame(cleaned_ptcl_table, columns = ["protocol_name"])
df.head()
# Out:
#            protocol_name
# 0                CityDAO
# 1            RariCapital
# 2               Frosties
# 3  Multiple IDO Projects
# 4              LooksRare

# %%
df1 = pd.DataFrame(final_dates, columns = ["date_of_attack"])
df1.head()
# Out:
#   date_of_attack
# 0     01/15/2022
# 1     01/15/2022
# 2     01/13/2022
# 3     01/12/2022
# 4     01/11/2022

# %%
df2 = pd.DataFrame(new_amt_table, columns = ["amount_lost"])
df2.head()
# Out:
#    amount_lost
# 0    29.67 ETH
# 1    $ 200,000
# 2  $ 1,000,000
# 3     5744 BNB
# 4            -

# %%
df3 = pd.DataFrame(attack_table, columns = ["attack_type"])
df3.head()
# Out:
#                     attack_type
# 0  Discord admin account hacked
# 1            price manipulation
# 2                          Scam
# 3                          Scam
# 4                   DDos attack

# %%
df4 = pd.DataFrame(description_table, columns = ["descripton_text"])
df4.head()
# Out:
#                                      descripton_text
# 0  CityDAO, an Ethereum-based community blockchai...
# 1  According to a tweet from Float Protocol, the ...
# 2  The creator of the NFT project Frosties abscon...
# 3  7 IDO projects on BSC are suspected to be runn...
# 4  NFT marketplace LooksRare suffered a DDoS atta...

# %%
df=df.join(df1)
df=df.join(df2)
df=df.join(df3)
df=df.join(df4)
df.head()
# Out:
#            protocol_name date_of_attack  amount_lost  \
# 0                CityDAO     01/15/2022    29.67 ETH
# 1            RariCapital     01/15/2022    $ 200,000
# 2               Frosties     01/13/2022  $ 1,000,000
# 3  Multiple IDO Projects     01/12/2022     5744 BNB
# 4              LooksRare     01/11/2022            -
#
#                     attack_type  \
# 0  Discord admin account hacked
# 1            price manipulation
# 2                          Scam
# 3                          Scam
# 4                   DDos attack
#
#                                      descripton_text
# 0  CityDAO, an Ethereum-based community blockchai...
# 1  According to a tweet from Float Protocol, the ...
# 2  The creator of the NFT project Frosties abscon...
# 3  7 IDO projects on BSC are suspected to be runn...
# 4  NFT marketplace LooksRare suffered a DDoS atta...

# %%
# Converting dataframe data to Excel
# The data stored accounts for slowmist.io landing page data
df.to_excel('sena_slowmist_ws.xlsx', index=False)
